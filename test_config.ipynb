# %%
from databricks.connect import DatabricksSession
 
spark = DatabricksSession.builder.getOrCreate()

# %%
spark.read.table("openeconomics.gold.couind_eurostat_sam_y")
# Out:
# DataFrame[c_orig: string, ind_ava: string, c_dest: string, ind_use: string, value: double, share: double, time_period: int]
